# %%
import pandas as pd
from dotenv import load_dotenv
from sqlalchemy import create_engine
from os import getenv
from datetime import datetime
from pprint import pprint
import matplotlib.pyplot as plt
# %matplotlib inline


_ =load_dotenv(override=True)

# %% [markdown]
# ### Households

# %%
url = f"postgresql://postgres:{getenv('SUPABASE_PWD')}@{getenv('SUPABASE_URL')}:5432/postgres"
engine = create_engine(url)

HL = '6a4e7955-aca0-4dab-8a13-0a6adb014b57'

households_query = f"""SELECT 
ph.id, ph.activation_code, ph.account_status, ph.client_id, ph.date_of_activation, ph.gas_ean, ph.electricity_ean, 
phd.build_year, phd.heating_type, phd.gas_connection, phd.gas_or_induction, phd.water_heating_type, 
hd.zipcode
FROM public.households ph 
JOIN public.household_house_details phd ON phd.household_id = ph.id 
JOIN public.household_details hd ON hd.household_id = ph.id 
WHERE client_id = '{HL}'
"""

# %%
households = pd.read_sql(households_query, engine)

# %%
households.head()
# Out:
#                                      id account_status  \
# 0  da3bc575-a364-42cd-be06-1d4d6407fc89         Active
# 1  f448318f-e7e0-4424-9ab1-b44e0c354882         Active
# 2  4d1dc58c-d3d0-4820-9b79-bac883b5b7a7         Active
# 3  dbb3de4f-eda5-4974-9317-09c0f86d6a5e         Active
# 4  b5943df0-36fc-4aef-81ab-afdabc1be1af         Active
#
#                               client_id        date_of_activation  \
# 0  6a4e7955-aca0-4dab-8a13-0a6adb014b57 2023-01-10 00:00:00+00:00
# 1  6a4e7955-aca0-4dab-8a13-0a6adb014b57 2022-12-24 00:00:00+00:00
# 2  6a4e7955-aca0-4dab-8a13-0a6adb014b57 2021-10-25 00:00:00+00:00
# 3  6a4e7955-aca0-4dab-8a13-0a6adb014b57 2021-10-24 00:00:00+00:00
# 4  6a4e7955-aca0-4dab-8a13-0a6adb014b57 2021-12-28 00:00:00+00:00
#
#               gas_ean     electricity_ean  build_year heating_type  \
# 0  871717730000094431  871687940008642729         NaN         None
# 1  871717730000067626  871687940031384184         NaN         None
# 2  871687940033224747  871687940033224730         NaN         None
# 3  871717710000317662  871687940008603423      1965.0         None
# 4                None  871687940032039533      2014.0   Warmtepomp
#
#   gas_connection gas_or_induction water_heating_type zipcode
# 0           None             None               None  5591TP
# 1           None             None               None  5595CD
# 2           None             None               None  5591MC
# 3           None             None               None  5591AH
# 4           None             None               None  5591TG

# %%
households.columns
# Out:
# Index(['id', 'account_status', 'client_id', 'date_of_activation', 'gas_ean',
#        'electricity_ean', 'build_year', 'heating_type', 'gas_connection',
#        'gas_or_induction', 'water_heating_type', 'zipcode'],
#       dtype='object')

# %%
print(f"Total number of households: {len(households)}")
print(f"Are all unique records?: {len(households) == len(households.drop_duplicates(subset='id'))}")
# Out:
# Total number of households: 2495
# Are all unique records?: True

# %%
households.to_csv("../data/spa_households.csv", sep=";")

# %% [markdown]
# ### Enrich

# %%
def build_years(row: pd.Series) -> pd.Series:
    bouwjaar = None
    if row["build_year"] < 1950:
        bouwjaar = "tot 1950"
    elif 1950 <= row["build_year"] < 1975:
        bouwjaar = "1950-1975"
    elif 1975 <= row["build_year"] < 1992:
        bouwjaar = "1975-1992"
    elif 1992 <= row["build_year"] < 2006:
        bouwjaar = "1992-2006"
    elif 2006 <= row["build_year"] <= 2015:
        bouwjaar = "2006-2015"
    elif 2015 < row["build_year"]:
        bouwjaar = "na 2015"
       
    row["bouwjaar"] = bouwjaar
    return row

# %%
households['postcode'] = households['zipcode'].str[:4]
households = households.apply(build_years, axis=1)
households['id'] = households['id'].astype('str')
households['date_of_activation'] = pd.to_datetime(households['date_of_activation'], utc=False).dt.tz_localize(None)  # convert to dt

# %% [markdown]
# ### 1.1 Gasloos

# %%
columns = ["gas_ean", "postcode", "bouwjaar"]
gasloos = households[columns].copy()

# %%
gasloos['gasloos'] = pd.isna(gasloos['gas_ean'])

# %%
per_bouwjaar = (
    gasloos.groupby('bouwjaar')['gasloos']
    .apply(lambda x: (x.sum() / len(x)) * 100)  # Calculate percentage
    .reset_index(name='gasloos %')    # Reset index and name the column
)

per_bouwjaar['gasloos %'] = per_bouwjaar['gasloos %'].round(2).astype(str) + '%'

# %%
per_postcode = (
    gasloos.groupby('postcode')['gasloos']
    .apply(lambda x: (x.sum() / len(x)) * 100)  # Calculate percentage
    .reset_index(name='gasloos %')    # Reset index and name the column
)
per_postcode['gasloos %'] = per_postcode['gasloos %'].round(2).astype(str) + '%'

# %%
per_bouwjaar
# Out:
#     bouwjaar gasloos %
# 0  1950-1975     2.35%
# 1  1975-1992     0.49%
# 2  1992-2006      1.1%
# 3  2006-2015     4.17%
# 4    na 2015    48.99%
# 5   tot 1950     3.64%

# %%
per_postcode
# Out:
#   postcode gasloos %
# 0     5591     4.33%
# 1     5595      5.7%
# 2     6029    23.14%

# %%
per_bouwjaar.to_csv('../data/gasloos_bouwjaar.csv', sep=';', index=False)
per_postcode.to_csv('../data/gasloos_postcode.csv', sep=';', index=False)

# %% [markdown]
# ### 1.2 Inductie

# %%
columns = ["postcode", "bouwjaar", "gas_or_induction"]
inductie = households[columns].copy()

# %%
inductie['gas_or_induction'] = inductie['gas_or_induction'].replace({'Induction': 'Inductie', '': None})

# %%
per_bouwjaar = (
    inductie.dropna(subset=['bouwjaar', 'gas_or_induction']).pivot_table(
        index='bouwjaar',
        columns='gas_or_induction',
        aggfunc='size',
        fill_value=0
    )
)

per_bouwjaar.columns.name = '#'

# Calculate percentages
per_bouwjaar_perc = per_bouwjaar.copy().div(per_bouwjaar.sum(axis=1), axis=0) * 100

# Format percentages
for col in per_bouwjaar.columns:
    per_bouwjaar_perc[col] = per_bouwjaar_perc[col].round(2).astype(str) + '%'

per_bouwjaar_perc.columns.name = ''

# %%
per_postcode = (
    inductie.dropna(subset=['postcode', 'gas_or_induction']).pivot_table(
        index='postcode',
        columns='gas_or_induction',
        aggfunc='size',
        fill_value=0
    )
)
per_postcode.columns.name = '#'

# Calculate percentages
per_postcode_perc = per_postcode.copy().div(per_postcode.sum(axis=1), axis=0) * 100

# Format percentages
for col in per_postcode_perc.columns:
    per_postcode_perc[col] = per_postcode_perc[col].round(2).astype(str) + '%'

per_postcode_perc.columns.name = ''

# %%
per_bouwjaar
# Out:
# #          Gas  Inductie
# bouwjaar
# 1950-1975   19        34
# 1975-1992   17        20
# 1992-2006    3         8
# 2006-2015    7         8
# na 2015      2         5
# tot 1950     2         5

# %%
per_bouwjaar_perc
# Out:
#               Gas Inductie
# bouwjaar
# 1950-1975  35.85%   64.15%
# 1975-1992  45.95%   54.05%
# 1992-2006  27.27%   72.73%
# 2006-2015  46.67%   53.33%
# na 2015    28.57%   71.43%
# tot 1950   28.57%   71.43%

# %%
per_postcode
# Out:
# #         Gas  Inductie
# postcode
# 5591       38        61
# 5595       11        19
# 6029        6         5

# %%
per_postcode_perc
# Out:
#              Gas Inductie
# postcode
# 5591      38.38%   61.62%
# 5595      36.67%   63.33%
# 6029      54.55%   45.45%

# %% [markdown]
# ### 1.3 Warmtepomp

# %%
columns = ["postcode", "bouwjaar", "heating_type"]
warmtepomp = households[columns].copy()

# %%
translations = {
    'Central heating boiler, Heat pump': 'Hybride', 
    'Heat pump': 'Warmtepomp', 
    'Heat pump, Central heating boiler': 'Hybride',
    'Heat pump, Underfloor heating': 'Warmtempomp',
    'Heat pump, Underfloor heating, Central heating boiler': 'Hybride',
    'Hybrid boiler': 'Hybride',
    'Hybrid boiler, Underfloor heating': 'Hybride',
    'Hybrid heat pump': 'Hybride',
    'Hybrid heat pump, Underfloor heating, Infrared panels': 'Hybride',
    'Hybride ketel': 'Hybride',
}
translations.update({'': None})

warmtepomp['heating_type'] = warmtepomp['heating_type'].replace(translations)

# %%
per_bouwjaar = (
    warmtepomp.dropna(subset=['bouwjaar', 'heating_type']).pivot_table(
        index='bouwjaar',
        columns='heating_type',
        aggfunc='size',
        fill_value=0
    )
)


per_bouwjaar.columns.name = '#'

# Calculate percentages
per_bouwjaar_perc = per_bouwjaar.copy().div(per_bouwjaar.sum(axis=1), axis=0) * 100

# Format percentages
for col in per_bouwjaar.columns:
    per_bouwjaar_perc[col] = per_bouwjaar_perc[col].round(2).astype(str) + '%'

per_bouwjaar_perc.columns.name = ''


per_bouwjaar = per_bouwjaar[["Warmtepomp", "Hybride"]]
per_bouwjaar_perc = per_bouwjaar_perc[["Warmtepomp", "Hybride"]]

# %%
per_bouwjaar
# Out:
# #          Warmtepomp  Hybride
# bouwjaar
# 1950-1975          14       14
# 1975-1992           7        7
# 1992-2006           6        6
# 2006-2015          14        6
# na 2015            72        2
# tot 1950            1        3

# %%
per_bouwjaar_perc
# Out:
#           Warmtepomp Hybride
# bouwjaar
# 1950-1975      5.11%   5.11%
# 1975-1992      3.72%   3.72%
# 1992-2006      6.82%   6.82%
# 2006-2015     14.29%   6.12%
# na 2015       63.16%   1.75%
# tot 1950       1.56%   4.69%

# %%
per_postcode = (
    warmtepomp.dropna(subset=['postcode', 'heating_type']).pivot_table(
        index='postcode',
        columns='heating_type',
        aggfunc='size',
        fill_value=0
    )
)
per_postcode.columns.name = '#'

# Calculate percentages
per_postcode_perc = per_postcode.copy().div(per_postcode.sum(axis=1), axis=0) * 100

# Format percentages
for col in per_postcode_perc.columns:
    per_postcode_perc[col] = per_postcode_perc[col].round(2).astype(str) + '%'

per_postcode_perc.columns.name = ''


per_postcode = per_postcode[["Warmtepomp", "Hybride"]]
per_postcode_perc = per_postcode_perc[["Warmtepomp", "Hybride"]]

# %%
per_postcode
# Out:
# #         Warmtepomp  Hybride
# postcode
# 5591              64       24
# 5595              24        9
# 6029              27        5

# %%
per_postcode_perc
# Out:
#          Warmtepomp Hybride
# postcode
# 5591         11.68%   4.38%
# 5595         12.06%   4.52%
# 6029         29.35%   5.43%

# %% [markdown]
# ### Gas

# %%
gas_usage_query = f"SELECT p4.query_date, p4.measurement_total, hh.id AS household_id, hh.account_status, hh.date_of_activation FROM public.p4_month_data p4 JOIN public.households hh ON hh.gas_ean = p4.meter_ean WHERE p4.type = 'gas' AND hh.client_id = '{HL}'"

# %%
gas = pd.read_sql(gas_usage_query, engine)

# %%
gas.to_csv('../data/spa_gas.csv', sep=';', index=False)

# %%
gas = gas[['household_id', 'account_status', 'query_date', 'measurement_total', 'date_of_activation']]  # sort columns
gas['date_of_activation'] = pd.to_datetime(gas['date_of_activation'], utc=False).dt.tz_localize(None)  # convert to dt
gas['query_date'] = pd.to_datetime(gas['query_date'])  # convert to dt
gas['household_id'] = gas['household_id'].astype('str')  # convert to string
gas.sort_values(by=['household_id', 'query_date'], inplace=True)  # sort
gas.reset_index(inplace=True)

# %%
gas.head(10)
# Out:
#    index                          household_id account_status query_date  \
# 0   3481  0034b1f4-64c4-434e-af78-7246829c9b42         Active 2024-08-31
# 1   3480  0034b1f4-64c4-434e-af78-7246829c9b42         Active 2024-09-30
# 2   3482  0034b1f4-64c4-434e-af78-7246829c9b42         Active 2024-10-31
# 3   3479  0034b1f4-64c4-434e-af78-7246829c9b42         Active 2024-12-31
# 4   3478  0034b1f4-64c4-434e-af78-7246829c9b42         Active 2025-01-31
# 5   5413  003a7b4d-492b-4d35-aded-f91321383a0a         Active 2024-08-31
# 6   5412  003a7b4d-492b-4d35-aded-f91321383a0a         Active 2024-09-30
# 7   5411  003a7b4d-492b-4d35-aded-f91321383a0a         Active 2024-10-31
# 8   5410  003a7b4d-492b-4d35-aded-f91321383a0a         Active 2024-12-31
# 9   5409  003a7b4d-492b-4d35-aded-f91321383a0a         Active 2025-01-31
#
#    measurement_total date_of_activation
# 0           5546.746         2021-10-30
# 1           5556.401         2021-10-30
# 2           5635.670         2021-10-30
# 3           6070.714         2021-10-30
# 4           6362.141         2021-10-30
# 5           6025.788         2021-09-30
# 6           6053.608         2021-09-30
# 7           6109.821         2021-09-30
# 8           6465.614         2021-09-30
# 9           6700.864         2021-09-30

# %%
before = len(gas)
gas = gas[gas['account_status'] == 'Active']
print(f"Dropped {before - len(gas)} readings for inactive accounts")
# Out:
# Dropped 9 readings for inactive accounts

# %%
# Calculate usage per household
for id in gas['household_id'].unique():
    subset = gas[gas['household_id'] == id]
    gas.loc[subset.index, 'usage'] = subset['measurement_total'].diff()
    gas.loc[subset.index, 'period'] = subset['query_date'].diff()

# %%
gas['month'] = gas['period'] < pd.Timedelta(days=32)  # because some measurements may be missing
gas = gas[gas['month']]
gas = gas[(gas['usage'] < 1500) & (gas['usage'] >= 0)]

# %%
plt.figure(figsize=(10, 6))
plt.hist(gas['usage'], bins=30, color='skyblue', edgecolor='black')
plt.title("Gas monthly usage (aug '24 - jan '25)")
plt.xlabel('m3')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Total gas usage per household for the period available in the database

# %%
total_usage = (
    gas.groupby('household_id')['usage']
    .apply(sum)
    .reset_index(name='total')    # Reset index and name the column
)
# Out:
# /var/folders/fr/dynq2jt113v40q17r07m78d40000gn/T/ipykernel_78908/2357521243.py:3: FutureWarning:
#
# The provided callable <built-in function sum> is currently using np.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string np.sum instead.

# %%
RELEVANT_USAGE = 30  # relavant m3 for period aug '24 - feb '25 to say 'no gas' or 'with gas'

# %%
total_usage.rename(columns={'household_id': 'id'}, inplace=True)
house_gas = pd.merge(households, total_usage, on='id', how='left')
house_gas['gasloos'] = pd.isna(house_gas['gas_ean'])
house_gas['no_usage'] = (pd.isna(house_gas['total'])) | (house_gas['total'] < RELEVANT_USAGE)

# %%
gas_but_no_gas = house_gas[~house_gas['gasloos'] & house_gas['no_usage'] & (house_gas['date_of_activation'] < datetime(2024, 9, 1))]
print(f"{len(gas_but_no_gas)} households have a gas meter but no (significant) usage")
print(f"{len(gas_but_no_gas.dropna(subset='total'))} of which have a total usage of < {RELEVANT_USAGE}m3 between august '24 and feb '25")
print("The rest we have no measurements")
# Out:
# 217 households have a gas meter but no (significant) usage
# 94 of which have a total usage of < 30m3 between august '24 and feb '25
# The rest we have no measurements

# %%
house_gas['gasloos'] = house_gas['gasloos'] | (house_gas['no_usage'] & (house_gas['date_of_activation'] < datetime(2024, 9, 1)) & ~pd.isna(house_gas['total']))

# %%
per_bouwjaar = (
    house_gas.groupby('bouwjaar')['gasloos']
    .apply(lambda x: (x.sum() / len(x)) * 100)  # Calculate percentage
    .reset_index(name='gasloos %')    # Reset index and name the column
)

per_bouwjaar['gasloos %'] = per_bouwjaar['gasloos %'].round(2).astype(str) + '%'
per_bouwjaar
# Out:
#     bouwjaar gasloos %
# 0  1950-1975     6.46%
# 1  1975-1992     4.17%
# 2  1992-2006     5.49%
# 3  2006-2015    10.71%
# 4    na 2015    53.69%
# 5   tot 1950     6.36%

# %%
per_postcode = (
    gasloos.groupby('postcode')['gasloos']
    .apply(lambda x: (x.sum() / len(x)) * 100)  # Calculate percentage
    .reset_index(name='gasloos %')    # Reset index and name the column
)
per_postcode['gasloos %'] = per_postcode['gasloos %'].round(2).astype(str) + '%'
per_postcode
# Out:
#   postcode gasloos %
# 0     5591     4.33%
# 1     5595      5.7%
# 2     6029    23.14%

# %% [markdown]
# ### Electricity

# %%
elec_usage_query = f"SELECT p4.query_date, p4.measurement_total, hh.id AS household_id, hh.account_status, hh.date_of_activation FROM public.p4_month_data p4 JOIN public.households hh ON hh.electricity_ean = p4.meter_ean WHERE p4.type = 'electricity' AND hh.client_id = '{HL}'"

# %%
elec = pd.read_sql(elec_usage_query, engine)
elec.to_csv('../data/spa_elec.csv', sep=';', index=False)

# %%
elec = elec[['household_id', 'account_status', 'query_date', 'measurement_total', 'date_of_activation']]  # sort columns
elec['date_of_activation'] = pd.to_datetime(elec['date_of_activation'], utc=False).dt.tz_localize(None)  # convert to dt
elec['query_date'] = pd.to_datetime(elec['query_date'])  # convert to dt
elec['household_id'] = elec['household_id'].astype('str')  # convert to string
elec.sort_values(by=['household_id', 'query_date'], inplace=True)  # sort
elec.reset_index(inplace=True)

# %%
before = len(elec)
elec = elec[elec['account_status'] == 'Active']
print(f"Dropped {before - len(elec)} readings for inactive accounts")
# Out:
# Dropped 0 readings for inactive accounts

# %%
# Calculate usage per household
for id in elec['household_id'].unique():
    subset = elec[elec['household_id'] == id]
    elec.loc[subset.index, 'usage'] = subset['measurement_total'].diff()

# %%
elec.head(10)
# Out:
#    index                          household_id account_status query_date  \
# 0   3756  0034b1f4-64c4-434e-af78-7246829c9b42         Active 2024-08-31
# 1   3755  0034b1f4-64c4-434e-af78-7246829c9b42         Active 2024-09-30
# 2   3754  0034b1f4-64c4-434e-af78-7246829c9b42         Active 2024-10-31
# 3   3753  0034b1f4-64c4-434e-af78-7246829c9b42         Active 2024-12-31
# 4   3752  0034b1f4-64c4-434e-af78-7246829c9b42         Active 2025-01-31
# 5   5843  003a7b4d-492b-4d35-aded-f91321383a0a         Active 2024-08-31
# 6   5842  003a7b4d-492b-4d35-aded-f91321383a0a         Active 2024-09-30
# 7   5841  003a7b4d-492b-4d35-aded-f91321383a0a         Active 2024-10-31
# 8   5839  003a7b4d-492b-4d35-aded-f91321383a0a         Active 2024-12-31
# 9   5840  003a7b4d-492b-4d35-aded-f91321383a0a         Active 2025-01-31
#
#    measurement_total date_of_activation     usage
# 0          15140.536         2021-10-30       NaN
# 1          15389.348         2021-10-30   248.812
# 2          15679.117         2021-10-30   289.769
# 3          16227.974         2021-10-30   548.857
# 4          16462.432         2021-10-30   234.458
# 5          15311.992         2021-09-30       NaN
# 6          15469.250         2021-09-30   157.258
# 7          15708.623         2021-09-30   239.373
# 8          16860.824         2021-09-30  1152.201
# 9          17621.481         2021-09-30   760.657
